# %%
print('jo')
# Out:
# jo

# %%
import tensorflow as tf
print(tf.__version__)
# Out:
# 2.12.0

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
dataset=pd.read_csv('Churn_Modelling.csv')
dataset.head()
# Out:
#    RowNumber  CustomerId   Surname  CreditScore Geography  Gender  Age  \
# 0          1    15634602  Hargrave          619    France  Female   42
# 1          2    15647311      Hill          608     Spain  Female   41
# 2          3    15619304      Onio          502    France  Female   42
# 3          4    15701354      Boni          699    France  Female   39
# 4          5    15737888  Mitchell          850     Spain  Female   43
#
#    Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 0       2       0.00              1          1               1
# 1       1   83807.86              1          0               1
# 2       8  159660.80              3          1               0
# 3       1       0.00              2          0               0
# 4       2  125510.82              1          1               1
#
#    EstimatedSalary  Exited
# 0        101348.88       1
# 1        112542.58       0
# 2        113931.57       1
# 3         93826.63       0
# 4         79084.10       0

# %%
x=dataset.iloc[:,3:13]
y=dataset.iloc[:,13]

# %%
x.head()
# Out:
#    CreditScore Geography  Gender  Age  Tenure    Balance  NumOfProducts  \
# 0          619    France  Female   42       2       0.00              1
# 1          608     Spain  Female   41       1   83807.86              1
# 2          502    France  Female   42       8  159660.80              3
# 3          699    France  Female   39       1       0.00              2
# 4          850     Spain  Female   43       2  125510.82              1
#
#    HasCrCard  IsActiveMember  EstimatedSalary
# 0          1               1        101348.88
# 1          0               1        112542.58
# 2          1               0        113931.57
# 3          0               0         93826.63
# 4          1               1         79084.10

# %%
#feature engineering
geography=pd.get_dummies(dataset['Geography'],drop_first=True)
gender=pd.get_dummies(dataset['Gender'],drop_first=True)

# %%
x=x.drop(['Gender','Geography'],axis=1)

# %%
x.head()
# Out:
#    CreditScore  Age  Tenure    Balance  NumOfProducts  HasCrCard  \
# 0          619   42       2       0.00              1          1
# 1          608   41       1   83807.86              1          0
# 2          502   42       8  159660.80              3          1
# 3          699   39       1       0.00              2          0
# 4          850   43       2  125510.82              1          1
#
#    IsActiveMember  EstimatedSalary
# 0               1        101348.88
# 1               1        112542.58
# 2               0        113931.57
# 3               0         93826.63
# 4               1         79084.10

# %%
#now concat as we have removed those stuff
x=pd.concat([x,geography,gender],axis=1)

# %%
x.head()
# Out:
#    CreditScore  Age  Tenure    Balance  NumOfProducts  HasCrCard  \
# 0          619   42       2       0.00              1          1
# 1          608   41       1   83807.86              1          0
# 2          502   42       8  159660.80              3          1
# 3          699   39       1       0.00              2          0
# 4          850   43       2  125510.82              1          1
#
#    IsActiveMember  EstimatedSalary  Germany  Spain  Male
# 0               1        101348.88        0      0     0
# 1               1        112542.58        0      1     0
# 2               0        113931.57        0      0     0
# 3               0         93826.63        0      0     0
# 4               1         79084.10        0      1     0

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test =train_test_split(x,y,random_state=0,test_size=0.2)

# %%
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()
X_train=sc.fit_transform(X_train)
X_test=sc.transform(X_test)

# %%
X_train
# Out:
# array([[ 0.16958176, -0.46460796,  0.00666099, ..., -0.5698444 ,
#          1.74309049, -1.09168714],
#        [-2.30455945,  0.30102557, -1.37744033, ...,  1.75486502,
#         -0.57369368,  0.91601335],
#        [-1.19119591, -0.94312892, -1.031415  , ..., -0.5698444 ,
#         -0.57369368, -1.09168714],
#        ...,
#        [ 0.9015152 , -0.36890377,  0.00666099, ..., -0.5698444 ,
#         -0.57369368,  0.91601335],
#        [-0.62420521, -0.08179119,  1.39076231, ..., -0.5698444 ,
#          1.74309049, -1.09168714],
#        [-0.28401079,  0.87525072, -1.37744033, ...,  1.75486502,
#         -0.57369368, -1.09168714]])

# %%
X_test
# Out:
# array([[-0.55204276, -0.36890377,  1.04473698, ...,  1.75486502,
#         -0.57369368, -1.09168714],
#        [-1.31490297,  0.10961719, -1.031415  , ..., -0.5698444 ,
#         -0.57369368, -1.09168714],
#        [ 0.57162971,  0.30102557,  1.04473698, ..., -0.5698444 ,
#          1.74309049, -1.09168714],
#        ...,
#        [-0.74791227, -0.27319958, -1.37744033, ..., -0.5698444 ,
#          1.74309049,  0.91601335],
#        [-0.00566991, -0.46460796, -0.33936434, ...,  1.75486502,
#         -0.57369368,  0.91601335],
#        [-0.79945688, -0.84742473,  1.04473698, ...,  1.75486502,
#         -0.57369368,  0.91601335]])

# %%
X_train.shape
# Out:
# (8000, 11)

# %%
#now creating ANN
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.layers import ReLU,ELU,LeakyReLU,PReLU
from tensorflow.keras.layers import Dropout

# %%
classifier=Sequential()

# %%
#adding input layer
classifier.add(Dense(units=11,activation='relu'))
classifier.add(Dropout(0.2))

# %%
#adding hidden layer-1
classifier.add(Dense(units=7,activation='relu'))
classifier.add(Dropout(0.3))

# %%
#adding hidden layer-2
classifier.add(Dense(units=6,activation='relu'))
classifier.add(Dropout(0.2))

# %%
#adding output layer
classifier.add(Dense(units=1,activation='sigmoid'))
classifier.add(Dropout(0.2))

# %%
classifier.compile(optimizer='adam',loss='binary_crossentropy',metrics=['accuracy'])

# %%
import tensorflow
opt=tensorflow.keras.optimizers.Adam(learning_rate=0.01)
#we can keep optimizer=opt

# %%
model_history=classifier.fit(X_train,y_train,validation_split=0.33,batch_size=10,epochs=100)
# Out:
# Epoch 1/100
# 536/536 [==============================] - 3s 4ms/step - loss: 1.1688 - accuracy: 0.6264 - val_loss: 0.4788 - val_accuracy: 0.7955
# Epoch 2/100
# 536/536 [==============================] - 3s 5ms/step - loss: 1.0267 - accuracy: 0.7779 - val_loss: 0.4688 - val_accuracy: 0.7955
# Epoch 3/100
# 536/536 [==============================] - 2s 4ms/step - loss: 1.0101 - accuracy: 0.7946 - val_loss: 0.4630 - val_accuracy: 0.7955
# Epoch 4/100
# 536/536 [==============================] - 2s 4ms/step - loss: 1.0564 - accuracy: 0.7960 - val_loss: 0.4555 - val_accuracy: 0.7955
# Epoch 5/100
# 536/536 [==============================] - 2s 4ms/step - loss: 0.9775 - accuracy: 0.7957 - val_loss: 0.4492 - val_accuracy: 0.7955
# Epoch 6/100
# 536/536 [==============================] - 2s 3ms/step - loss: 0.9885 - accuracy: 0.7962 - val_loss: 0.4449 - val_accuracy: 0.7955
# Epoch 7/100
# 536/536 [==============================] - 2s 3ms/step - loss: 1.0063 - accuracy: 0.7962 - val_loss: 0.4444 - val_accuracy: 0.7955
# Epoch 8/100
# 536/536 [==============================] - 2s 4ms/step - loss: 0.9562 - accuracy: 0.7962 - val_loss: 0.4430 - val_accuracy: 0.7955
# Epoch 9/100
# 536/536 [==============================] - 3s 6ms/step - loss: 1.0514 - accuracy: 0.7962 - val_loss: 0.4379 - val_accuracy: 0.7955
# Epoch 10/100
# 536/536 [==============================] - 2s 4ms/step - loss: 0.9955 - accuracy: 0.7962 - val_loss: 0.4315 - val_accuracy: 0.7955
# Epoch 11/100
# 536/536 [==============================] - 2s 3ms/step - loss: 1.0271 - accuracy: 0.7962 - val_loss: 0.4301 - val_accuracy: 0.7955
# Epoch 12/100
# 536/536 [==============================] - 2s 3ms/step - loss: 0.9677 - accuracy: 0.7962 - val_loss: 0.4232 - val_accuracy: 0.7955
# Epoch 13/100
# 536/536 [==============================] - 2s 3ms/step - loss: 1.0149 - accuracy: 0.7962 - val_loss: 0.4215 - val_accuracy: 0.7955
# Epoch 14/100
# 536/536 [==============================] - 2s 3ms/step - loss: 0.9263 - accuracy: 0.7962 - val_loss: 0.4197 - val_accuracy: 0.7955
# Epoch 15/100
# 536/536 [==============================] - 2s 5ms/step - loss: 0.9376 - accuracy: 0.7962 - val_loss: 0.4154 - val_accuracy: 0.7955
# Epoch 16/100
# 536/536 [==============================] - 3s 5ms/step - loss: 0.9957 - accuracy: 0.7962 - val_loss: 0.4115 - val_accuracy: 0.7955
# Epoch 17/100
# 536/536 [==============================] - 2s 5ms/step - loss: 0.9890 - accuracy: 0.7962 - val_loss: 0.4084 - val_accuracy: 0.7955
# Epoch 18/100
# 536/536 [==============================] - 2s 4ms/step - loss: 0.9254 - accuracy: 0.7962 - val_loss: 0.4072 - val_accuracy: 0.7955
# Epoch 19/100
# 536/536 [==============================] - 3s 5ms/step - loss: 0.9846 - accuracy: 0.7962 - val_loss: 0.4058 - val_accuracy: 0.7955
# Epoch 20/100
# 536/536 [==============================] - 4s 7ms/step - loss: 0.9326 - accuracy: 0.7962 - val_loss: 0.4037 - val_accuracy: 0.7955
# Epoch 21/100
# 536/536 [==============================] - 4s 7ms/step - loss: 0.9720 - accuracy: 0.7962 - val_loss: 0.4050 - val_accuracy: 0.7955
# Epoch 22/100
# 536/536 [==============================] - 3s 5ms/step - loss: 0.9892 - accuracy: 0.7983 - val_loss: 0.3984 - val_accuracy: 0.7955
# Epoch 23/100
# 536/536 [==============================] - 3s 5ms/step - loss: 0.9603 - accuracy: 0.8209 - val_loss: 0.3987 - val_accuracy: 0.7955
# Epoch 24/100
# 536/536 [==============================] - 2s 4ms/step - loss: 0.9790 - accuracy: 0.8207 - val_loss: 0.3953 - val_accuracy: 0.7955
# Epoch 25/100
# 536/536 [==============================] - 3s 5ms/step - loss: 0.9680 - accuracy: 0.8188 - val_loss: 0.3918 - val_accuracy: 0.7955
# Epoch 26/100
# 536/536 [==============================] - 2s 4ms/step - loss: 0.9556 - accuracy: 0.8209 - val_loss: 0.3902 - val_accuracy: 0.7955
# Epoch 27/100
# 536/536 [==============================] - 2s 4ms/step - loss: 0.
100
# 536/536 [==============================] - 3s 5ms/step - loss: 0.9798 - accuracy: 0.8298 - val_loss: 0.3674 - val_accuracy: 0.8353
# Epoch 92/100
# 536/536 [==============================] - 2s 4ms/step - loss: 0.9098 - accuracy: 0.8265 - val_loss: 0.3678 - val_accuracy: 0.8277
# Epoch 93/100
# 536/536 [==============================] - 2s 4ms/step - loss: 0.9458 - accuracy: 0.8281 - val_loss: 0.3670 - val_accuracy: 0.8273
# Epoch 94/100
# 536/536 [==============================] - 2s 4ms/step - loss: 0.9021 - accuracy: 0.8324 - val_loss: 0.3649 - val_accuracy: 0.8379
# Epoch 95/100
# 536/536 [==============================] - 2s 3ms/step - loss: 0.9227 - accuracy: 0.8306 - val_loss: 0.3662 - val_accuracy: 0.8357
# Epoch 96/100
# 536/536 [==============================] - 2s 4ms/step - loss: 0.9245 - accuracy: 0.8283 - val_loss: 0.3676 - val_accuracy: 0.8372
# Epoch 97/100
# 536/536 [==============================] - 2s 4ms/step - loss: 0.9339 - accuracy: 0.8283 - val_loss: 0.3684 - val_accuracy: 0.8239
# Epoch 98/100
# 536/536 [==============================] - 2s 4ms/step - loss: 0.8678 - accuracy: 0.8321 - val_loss: 0.3651 - val_accuracy: 0.8364
# Epoch 99/100
# 536/536 [==============================] - 2s 4ms/step - loss: 0.9245 - accuracy: 0.8311 - val_loss: 0.3675 - val_accuracy: 0.8395
# Epoch 100/100
# 536/536 [==============================] - 2s 4ms/step - loss: 0.9340 - accuracy: 0.8298 - val_loss: 0.3691 - val_accuracy: 0.8251

# %%
#Early stopping-when accuracy is not at all increasing automatically the training will stop.below stuff taken
# from keras documentation.From this we can know how many epochs is needed.
import tensorflow as tf
early_stopping=tf.keras.callbacks.EarlyStopping(
    monitor="val_loss",
    min_delta=0.0001,
    patience=20,
    verbose=1,
    mode="auto",
    baseline=None,
    restore_best_weights=False,
)

# %%
model_history=classifier.fit(X_train,y_train,validation_split=0.33,batch_size=10,epochs=1000,callbacks=early_stopping)
# Out:
# Epoch 1/1000
# 536/536 [==============================] - 2s 4ms/step - loss: 0.8933 - accuracy: 0.8352 - val_loss: 0.3663 - val_accuracy: 0.8398
# Epoch 2/1000
# 536/536 [==============================] - 2s 4ms/step - loss: 0.8917 - accuracy: 0.8291 - val_loss: 0.3681 - val_accuracy: 0.8353
# Epoch 3/1000
# 536/536 [==============================] - 2s 3ms/step - loss: 0.8914 - accuracy: 0.8294 - val_loss: 0.3650 - val_accuracy: 0.8372
# Epoch 4/1000
# 536/536 [==============================] - 3s 5ms/step - loss: 0.9479 - accuracy: 0.8304 - val_loss: 0.3645 - val_accuracy: 0.8444
# Epoch 5/1000
# 536/536 [==============================] - 2s 4ms/step - loss: 0.9184 - accuracy: 0.8304 - val_loss: 0.3660 - val_accuracy: 0.8466
# Epoch 6/1000
# 536/536 [==============================] - 2s 4ms/step - loss: 0.9262 - accuracy: 0.8291 - val_loss: 0.3661 - val_accuracy: 0.8436
# Epoch 7/1000
# 536/536 [==============================] - 2s 3ms/step - loss: 0.9481 - accuracy: 0.8308 - val_loss: 0.3672 - val_accuracy: 0.8368
# Epoch 8/1000
# 536/536 [==============================] - 2s 3ms/step - loss: 0.9388 - accuracy: 0.8345 - val_loss: 0.3689 - val_accuracy: 0.8372
# Epoch 9/1000
# 536/536 [==============================] - 2s 4ms/step - loss: 0.9438 - accuracy: 0.8304 - val_loss: 0.3681 - val_accuracy: 0.8345
# Epoch 10/1000
# 536/536 [==============================] - 2s 4ms/step - loss: 0.9034 - accuracy: 0.8308 - val_loss: 0.3696 - val_accuracy: 0.8330
# Epoch 11/1000
# 536/536 [==============================] - 3s 5ms/step - loss: 0.9473 - accuracy: 0.8265 - val_loss: 0.3723 - val_accuracy: 0.8262
# Epoch 12/1000
# 536/536 [==============================] - 2s 3ms/step - loss: 0.8937 - accuracy: 0.8332 - val_loss: 0.3670 - val_accuracy: 0.8398
# Epoch 13/1000
# 536/536 [==============================] - 2s 4ms/step - loss: 0.8881 - accuracy: 0.8321 - val_loss: 0.3672 - val_accuracy: 0.8417
# Epoch 14/1000
# 536/536 [==============================] - 2s 4ms/step - loss: 0.9002 - accuracy: 0.8302 - val_loss: 0.3722 - val_accuracy: 0.8349
# Epoch 15/1000
# 536/536 [==============================] - 2s 4ms/step - loss: 0.9565 - accuracy: 0.8326 - val_loss: 0.3725 - val_accuracy: 0.8391
# Epoch 16/1000
# 536/536 [==============================] - 2s 4ms/step - loss: 0.8798 - accuracy: 0.8281 - val_loss: 0.3710 - val_accuracy: 0.8395
# Epoch 17/1000
# 536/536 [==============================] - 2s 4ms/step - loss: 0.9714 - accuracy: 0.8289 - val_loss: 0.3695 - val_accuracy: 0.8376
# Epoch 18/1000
# 536/536 [==============================] - 2s 4ms/step - loss: 0.8676 - accuracy: 0.8302 - val_loss: 0.3669 - val_accuracy: 0.8413
# Epoch 19/1000
# 536/536 [==============================] - 2s 3ms/step - loss: 0.9158 - accuracy: 0.8300 - val_loss: 0.3704 - val_accuracy: 0.8379
# Epoch 20/1000
# 536/536 [==============================] - 2s 4ms/step - loss: 0.8892 - accuracy: 0.8272 - val_loss: 0.3699 - val_accuracy: 0.8364
# Epoch 21/1000
# 536/536 [==============================] - 2s 4ms/step - loss: 0.9329 - accuracy: 0.8326 - val_loss: 0.3697 - val_accuracy: 0.8319
# Epoch 22/1000
# 536/536 [==============================] - 2s 4ms/step - loss: 0.8924 - accuracy: 0.8356 - val_loss: 0.3649 - val_accuracy: 0.8448
# Epoch 23/1000
# 536/536 [==============================] - 2s 4ms/step - loss: 0.8897 - accuracy: 0.8332 - val_loss: 0.3658 - val_accuracy: 0.8451
# Epoch 24/1000
# 536/536 [==============================] - 3s 5ms/step - loss: 0.9160 - accuracy: 0.8326 - val_loss: 0.3635 - val_accuracy: 0.8448
# Epoch 25/1000
# 536/536 [==============================] - 3s 5ms/step - loss: 0.9309 - accuracy: 0.8337 - val_loss: 0.3669 - val_accuracy: 0.8342
# Epoch 26/1000
# 536/536 [==============================] - 2s 3ms/step - loss: 1.0149 - accuracy: 0.8287 - val_loss: 0.3676 - val_accuracy: 0.8323
# Epoch 27/1000
# 536/536 [==============================] - 2s 3ms/step - loss: 0.8944 - accuracy: 0.8350 - val_loss: 0.3684 - val_accuracy: 0.8391
# Epoch 28/1000
# 536/536 [==============================] - 2s 4ms/step - loss: 0.9385 - accuracy: 0.8281 - val_loss: 0.3653 - val_accuracy: 0.8432
# Epoch 29/1000
# 536/536 [==============================] - 2s 4ms/step - loss: 0.8828 - accuracy: 0.8293 - val_loss: 0.3657 - val_accuracy: 0.8360
# Epoch 30/1000
# 536/536 [==============================] - 2s 4ms/step - loss: 0.8907 - accuracy: 0.8345 - val_loss: 0.3664 - val_accuracy: 0.8425
# Epoch 31/1000
# 536/536 [==============================] - 2s 4ms/step - loss: 0.9250 - accuracy: 0.8308 - val_loss: 0.3662 - val_accuracy: 0.8395
# Epoch 32/1000
# 536/536 [==============================] - 2s 4ms/step - loss: 0.9275 - accuracy: 0.8313 - val_loss: 0.3650 - val_accuracy: 0.8466
# Epoch 33/1000
# 536/536 [==============================] - 2s 3ms/step - loss: 0.9218 - accuracy: 0.8291 - val_loss: 0.3652 - val_accuracy: 0.8448
# Epoch 34/1000
# 536/536 [==============================] - 2s 4ms/step - loss: 0.9425 - accuracy: 0.8341 - val_loss: 0.3691 - val_accuracy: 0.8364
# Epoch 35/1000
# 536/536 [==============================] - 2s 3ms/step - loss: 0.9473 - accuracy: 0.8354 - val_loss: 0.3660 - val_accuracy: 0.8406
# Epoch 36/1000
# 536/536 [==============================] - 2s 3ms/step - loss: 0.9513 - accuracy: 0.8285 - val_loss: 0.3657 - val_accuracy: 0.8425
# Epoch 37/1000
# 536/536 [==============================] - 2s 4ms/step - loss: 0.9257 - accuracy: 0.8356 - val_loss: 0.3645 - val_accuracy: 0.8432
# Epoch 38/1000
# 536/536 [==============================] - 3s 5ms/step - loss: 0.9311 - accuracy: 0.8309 - val_loss: 0.3676 - val_accuracy: 0.8402
# Epoch 39/1000
# 536/536 [==============================] - 2s 4ms/step - loss: 0.9177 - accuracy: 0.8324 - val_loss: 0.3649 - val_accuracy: 0.8421
# Epoch 40/1000
# 536/536 [==============================] - 2s 4ms/step - loss: 0.9463 - accuracy: 0.8339 - val_loss: 0.3667 - val_accuracy: 0.8421
# Epoch 41/1000
# 536/536 [==============================] - 2s 4ms/step - loss: 0.8950 - accuracy: 0.8337 - val_loss: 0.3669 - val_accuracy: 0.8387
# Epoch 42/1000
# 536/536 [==============================] - 2s 4ms/step - loss: 0.9510 - accuracy: 0.8317 - val_loss: 0.3641 - val_accuracy: 0.8410
# Epoch 43/1000
# 536/536 [==============================] - 2s 4ms/step - loss: 0.9348 - accuracy: 0.8281 - val_loss: 0.3676 - val_accuracy: 0.8395
# Epoch 44/1000
# 536/536 [==============================] - 3s 5ms/step - loss: 0.9051 - accuracy: 0.8328 - val_loss: 0.3641 - val_accuracy: 0.8459
# Epoch 44: early stopping

# %%
#see in the above early stopping gor excected and model stopped training
model_history.history.keys()
# Out:
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy'])

# %%
plt.plot(model_history.history['accuracy'])
plt.plot(model_history.history['val_accuracy'])
plt.title('model accuracy')
plt.xlabel('accuracy')
plt.ylabel('epoch')
plt.legend(['train','test'],loc='upper left')
plt.show()

# %%
plt.plot(model_history.history['loss'])
plt.plot(model_history.history['val_loss'])
plt.title('model loss')
plt.xlabel('loss')
plt.ylabel('epoch')
plt.legend(['train','test'],loc='upper left')
plt.show()

# %%
y_pred=classifier.predict(X_test)
y_pred=(y_pred>=0.5)
# Out:
# 63/63 [==============================] - 0s 1ms/step

# %%
#create confusion matrix
from sklearn.metrics import confusion_matrix
cm=confusion_matrix(y_test,y_pred)
cm
# Out:
# array([[1567,   28],
#        [ 252,  153]])

# %%
#calculate accuracy
from sklearn.metrics import accuracy_score
score=accuracy_score(y_pred,y_test)
score
# Out:
# 0.86

# %%
#get the weights
classifier.get_weights()
# Out:
# [array([[ 7.36528710e-02,  1.68990776e-01, -2.43458465e-01,
#           4.25610365e-03, -7.29788914e-02, -2.16833651e-01,
#           1.73466876e-02, -1.27103508e-01,  1.08838864e-01,
#          -6.07052147e-02, -7.36925155e-02],
#         [-8.90016019e-01,  2.39571363e-01, -3.90236735e-01,
#           2.38581359e-01,  1.79292753e-01,  6.55512691e-01,
#          -8.86815071e-01,  1.21208094e-01, -1.36594847e-01,
#           6.57354653e-01, -8.40254545e-01],
#         [ 1.77841000e-02,  2.39781722e-01,  1.22149482e-01,
#           4.92319204e-02,  4.49497588e-02, -8.42391476e-02,
#          -4.11525518e-02, -3.35654281e-02,  4.60583717e-02,
#           3.92478779e-02, -1.16227724e-01],
#         [-1.08687706e-01, -1.70306209e-03,  1.28445514e-02,
#           1.31337479e-01, -6.63010061e-01, -3.19766641e-01,
#          -2.42464736e-01,  3.23533237e-01, -9.81320739e-01,
#          -5.49104214e-02,  1.29727004e-02],
#         [ 2.85887092e-01, -1.60539076e-02,  2.52763420e-01,
#           1.10490155e+00, -7.93244541e-01, -7.49904037e-01,
#           8.70454460e-02,  1.01244402e+00,  4.52392757e-01,
#           1.94300730e-02,  2.35646263e-01],
#         [-3.53151448e-02,  4.39872779e-02,  1.64662302e-01,
#           2.94340309e-02,  4.52997256e-03, -2.82444842e-02,
#          -7.41566569e-02,  3.40962666e-04, -2.61094961e-02,
#          -3.97193879e-02, -8.83268416e-02],
#         [ 8.66964981e-02,  7.30378449e-01,  4.50689316e-01,
#          -2.87785292e-01, -1.54951647e-01, -1.54972032e-01,
#          -1.11672781e-01, -1.24170028e-01,  1.57854527e-01,
#           3.99577647e-01, -9.61149335e-02],
#         [ 1.60111245e-02, -2.00460497e-02,  1.15889750e-01,
#           6.69717323e-03,  6.60044402e-02,  8.14351067e-02,
#          -1.66762605e-01,  1.01637952e-01,  4.28531803e-02,
#          -1.42046446e-02,  8.68981034e-02],
#         [-2.55233407e-01, -2.12046400e-01, -2.48207629e-01,
#          -8.09858292e-02,  2.93306857e-01,  1.10781744e-01,
#          -4.18881118e-01, -1.05519697e-01,  4.81157273e-01,
#           3.26514058e-03, -1.21499576e-01],
#         [-1.69425800e-01,  1.97078854e-01,  6.25448003e-02,
#           1.90645717e-02,  5.11901919e-03, -1.61887810e-01,
#          -3.25904518e-01,  1.50726318e-01,  6.68800995e-02,
#           6.58865925e-03, -2.50428408e-01],
#         [ 2.21091464e-01,  1.24170624e-01,  2.37554684e-01,
#           7.84401298e-02, -9.94182453e-02,  3.49562392e-02,
#           3.29871714e-01, -1.71051756e-01,  1.94083750e-01,
#           3.63785215e-02, -1.01705171e-01]], dtype=float32),
#  array([ 0.7926625 , -0.7213583 ,  0.54552567, -1.3742794 , -0.46669415,
#         -0.53451496,  0.2859915 , -1.5854714 , -0.4627531 , -1.3951117 ,
#          0.5196407 ], dtype=float32),
#  array([[ 0.6571901 ,  0.02001037,  0.02885512,  0.09034087, -0.53338337,
#           0.01489807, -0.24311179],
#         [ 0.35367996,  0.05494124,  0.13880351,  0.06741633, -0.5162158 ,
#          -0.00909279, -0.6927473 ],
#         [-0.14480077,  0.15254961,  0.15386876,  0.22640401, -0.5725579 ,
#           0.16201085,  0.1980273 ],
#         [-0.68081266, -0.8739319 , -0.85026014, -1.1400055 ,  0.7316643 ,
#          -0.9967876 ,  0.7677835 ],
#         [-0.5531477 , -1.4188439 , -0.3100502 , -0.7779155 ,  0.06010506,
#          -0.21674769,  0.24572463],
#         [ 0.02368533, -0.54185057, -0.05520846, -0.6390909 ,  0.08889234,
#          -0.151066  ,  0.2769727 ],
#         [-0.29852915,  0.10003408,  0.18584682,  0.23347694, -0.41721752,
#           0.21683544, -0.32190362],
#         [-1.434272  , -1.506486  , -1.3625097 , -1.95626   ,  0.979846  ,
#          -1.8419331 ,  1.1566201 ],
#         [ 0.25781032,  0.36425108,  0.26542646,  0.5520507 , -0.21712233,
#           0.42960736, -0.10988214],
#         [ 0.8541843 ,  0.3508609 ,  0.8392811 ,  1.0602082 , -1.2518604 ,
#           0.5033485 , -0.8600161 ],
#         [-0.256741  ,  0.05196445,  0.10838107,  0.09758972, -0.50746816,
#           0.12911843, -0.2629143 ]], dtype=float32),
#  array([-0.04948477,  0.13622871,  0.07511427,  0.20129332,  0.16166744,
#          0.07845967, -0.18722971], dtype=float32),
#  array([[ 0.23481548,  0.39504993,  0.18936352,  0.23265278,  0.43660355,
#          -1.6339084 ],
#         [ 0.36043805,  0.578934  ,  0.22548983,  0.33558455,  0.50709516,
#          -1.0296553 ],
#         [ 0.6315144 ,  0.29570735, -0.4762504 ,  0.36571273,  0.40173358,
#          -1.0769919 ],
#         [ 0.634105  , -1.3187017 ,  0.7154224 ,  0.35183695,  0.33333752,
#          -0.623572  ],
#         [-1.4826291 , -0.21299513, -1.6136706 , -2.1251538 , -1.2674755 ,
#           0.8877586 ],
#         [ 0.06034473,  0.32213548,  0.1332716 ,  0.04067108,  0.3683542 ,
#          -0.9577525 ],
#         [-1.6722533 , -0.33614707, -0.9443508 , -1.2561673 , -1.0517238 ,
#           0.31587893]], dtype=float32),
#  array([3.4908193e-01, 2.7982448e-04, 9.6959308e-02, 1.9921975e-01,
#         3.3337229e-01, 4.3571666e-01], dtype=float32),
#  array([[-0.31050542],
#         [-0.74555063],
#         [-0.65353245],
#         [-0.5543918 ],
#         [-0.40641   ],
#         [ 0.98152304]], dtype=float32),
#  array([-0.6897072], dtype=float32)]

# %%
from tensorflow.keras.models import save_model, load_model
import pickle

# Assuming 'model_history' is the history object returned by classifier.fit
# and 'model_history.model' is your TensorFlow/Keras model

# Save the model
model_history.model.save('model_tf.h5')

# Save the model history using pickle
with open('model_history.pkl', 'wb') as file:
    pickle.dump(model_history.history, file)

# Load the model
loaded_model_tf = load_model('model_tf.h5')

# Load the model history using pickle
with open('model_history.pkl', 'rb') as file:
    loaded_model_history = pickle.load(file)

# %%
loaded_model = load_model('model_tf.h5')
loaded_model

# %%
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-77-37b2f2fdb15f> in <cell line: 1>()
# ----> 1 loaded_model.head
#
# AttributeError: 'Sequential' object has no attribute 'head'
